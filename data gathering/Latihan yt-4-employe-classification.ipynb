# %% [markdown]
# # Data Preparation

# %% [markdown]
# import library yang dibutuhkan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Employee.csv')

df = df.copy()
# df = pd.DataFrame(df)

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1889

# %%
# hapus data yang terduplikasi
df.drop_duplicates(inplace =  True)

# %%
# Mengelompokan data berdasarkan kolom Education lalu menghitung rata-rata umur
df.groupby("Education")["Age"].mean()
# Out:
# Education
# Bachelors    31.306443
# Masters      30.149137
# PHD          29.769231
# Name: Age, dtype: float64

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 4                             2           1
# ...                         ...         ...
# 4645                          2           0
# 4647                          2           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
#
# [2764 rows x 9 columns]

# %%
# Mengurutkan berdasarkan JoiningYear 
df.sort_values(by="JoiningYear", ascending = True)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 3052  Bachelors         2012  Bangalore            3   34    Male          No
# 3054  Bachelors         2012  Bangalore            3   39  Female          No
# 3055  Bachelors         2012  Bangalore            3   41    Male          No
# 3058  Bachelors         2012  Bangalore            3   33    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 2221  Bachelors         2018       Pune            3   29    Male         Yes
# 2529    Masters         2018  New Delhi            3   30  Female          No
# 70    Bachelors         2018  Bangalore            3   23  Female          No
# 3267  Bachelors         2018  New Delhi            3   35  Female          No
# 3293  Bachelors         2018  Bangalore            3   35    Male          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4651                          2           0
# 3052                          1           0
# 3054                          2           0
# 3055                          3           0
# 3058                          2           0
# ...                         ...         ...
# 2221                          1           1
# 2529                          4           1
# 70                            1           1
# 3267                          2           1
# 3293                          1           1
#
# [2764 rows x 9 columns]

# %% [markdown]
# # Menampilkan histogram Frequency umur

# %%
plt.hist(df["Age"], bins = 'auto')
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age")
plt.show()

# %%
sns.countplot(data = df, x = "Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Count of genders")
plt.show()

# %%
sns.boxplot(data = df, y = "ExperienceInCurrentDomain")
plt.xlabel("Experience In Current Domain")
plt.title("Boxplot of Experience - Domain")
plt.show()

# %%
plt.scatter(df["Age"], df["ExperienceInCurrentDomain"])
plt.xlabel("Age")
plt.ylabel("Experience in current Domain")
plt.title("Experience Domain - Age Scatter Plot")
plt.show()

# %%
df.groupby("PaymentTier")["LeaveOrNot"].value_counts()
# Out:
# PaymentTier  LeaveOrNot
# 1            0              141
#              1               77
# 2            1              343
#              0              227
# 3            0             1308
#              1              668
# Name: count, dtype: int64

# %%
# tampilkan rata rata umur dari df LeaveOrNot == 1
df[df["LeaveOrNot"] == 1]["Age"].mean()
# Out:
# 30.22426470588235

# %%
# tampilkan rata rata PaymentTier dari df LeaveOrNot == 1
df[df["LeaveOrNot"] == 1]["PaymentTier"].mean()
# Out:
# 2.5431985294117645

# %%
df.groupby("City")['City'].count()
# Out:
# City
# Bangalore    1171
# New Delhi     792
# Pune          801
# Name: City, dtype: int64

# %%
# menghirung persentase EverBenched yang telah dikelompokan
benched_percentage = df.groupby("EverBenched")["EverBenched"].count() / len(df) * 100

# %%
benched_percentage
# Out:
# EverBenched
# No     86.939219
# Yes    13.060781
# Name: EverBenched, dtype: float64

# %%
df.groupby(["Education", "Gender"])["Age"].mean()
# Out:
# Education  Gender
# Bachelors  Female    30.929530
#            Male      31.619313
# Masters    Female    30.348921
#            Male      29.994429
# PHD        Female    29.730159
#            Male      29.795699
# Name: Age, dtype: float64

# %%
# menghitung deviasi standar ExperienceInCurrentDomain untuk setiap kelompok payment tier
df.groupby("PaymentTier")["ExperienceInCurrentDomain"].std()
# Out:
# PaymentTier
# 1    1.657295
# 2    1.543400
# 3    1.624992
# Name: ExperienceInCurrentDomain, dtype: float64

# %%
df.groupby(["JoiningYear", "Gender"])["Gender"].count()
# Out:
# JoiningYear  Gender
# 2012         Female    127
#              Male      181
# 2013         Female    175
#              Male      221
# 2014         Female    163
#              Male      222
# 2015         Female    265
#              Male      199
# 2016         Female    123
#              Male      187
# 2017         Female    284
#              Male      378
# 2018         Female     98
#              Male      141
# Name: Gender, dtype: int64

# %%
sns.violinplot(data = df, x = "PaymentTier", y = "Age")
plt.xlabel("Payment Tier")
plt.ylabel("Age")
plt.show()

# %%
sns.pairplot(df[["Age", "ExperienceInCurrentDomain", "JoiningYear"]])
plt.show()
# Out:
# C:\Users\azrul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
city_leave_counts = df.groupby("City")["LeaveOrNot"].value_counts().unstack()
city_leave_counts.plot(kind = "bar", stacked = True)
plt.xlabel("City")
plt.ylabel("Count")
plt.legend(title = "LeaveOrNot")
plt.show()

# %%
sns.boxplot(data = df, x = "Gender", y = "ExperienceInCurrentDomain")
plt.xlabel("Gender")
plt.ylabel("Experience in current Domain")
plt.title("Box Plot of Experience Domain - Gender")
plt.show()

# %%
sns.histplot(df["JoiningYear"], kde = True)
plt.xlabel("Joining Year")
plt.ylabel("Frequency")

plt.show()

# %%
grouped = df.groupby(["Education", "Gender"])["ExperienceInCurrentDomain"].mean().unstack()

# %%
grouped.plot(kind = "bar")
plt.xlabel("Education")
plt.ylabel("Average Experience in Current Domain")
plt.show()

# %%
grouped = df.groupby(["JoiningYear", "EverBenched"])["EverBenched"].count().unstack()

# %%
grouped.plot(kind = "area", stacked = True)
plt.xlabel("Joining Year")
plt.ylabel("Count")
plt.legend(title = "EverBenched")
plt.show()

# %%
sns.boxplot(data = df, x = "Education", y = "Age", hue = "EverBenched")
plt.xlabel("Education")
plt.ylabel("Age")
plt.legend(title = "EverBenched")
plt.show()

# %%
g = sns.FacetGrid(df, col = "City", hue = "Gender")
g.map(plt.hist, "ExperienceInCurrentDomain")
g.set_axis_labels("Experience in Current Doamain", "Count")
g.add_legend(title = "Gender")
plt.show()
# Out:
# C:\Users\azrul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
grouped = df.groupby(["JoiningYear", "City"])["Age"].mean().unstack()

# %%
grouped.plot(kind = "line", marker = "o")
plt.ylabel("Average Age")
plt.xlabel("Joining Age")
plt.legend(title = "EverBenched")
plt.show()

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %%
# ambil semua baris data dan kolom kecuali kolom paling belakang
x = df.iloc[:,:-1]

# %%
x
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
#       ExperienceInCurrentDomain
# 0                             0
# 1                             3
# 2                             2
# 3                             5
# 4                             2
# ...                         ...
# 4645                          2
# 4647                          2
# 4649                          2
# 4650                          5
# 4651                          2
#
# [2764 rows x 8 columns]

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 4645    0
# 4647    0
# 4649    1
# 4650    1
# 4651    0
# Name: LeaveOrNot, Length: 2764, dtype: int64

# %%
x.drop(columns = ["JoiningYear", "City", "Age"], inplace = True)

# %%
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

# %%
x["Education"] = labelencoder.fit_transform(x["Education"])

# %%
x["Gender"] = labelencoder.fit_transform(x["Gender"])

# %%
x["EverBenched"] = labelencoder.fit_transform(x["EverBenched"])

# %%
x
# Out:
#       Education  PaymentTier  Gender  EverBenched  ExperienceInCurrentDomain
# 0             0            3       1            0                          0
# 1             0            1       0            0                          3
# 2             0            3       0            0                          2
# 3             1            3       1            0                          5
# 4             1            3       1            1                          2
# ...         ...          ...     ...          ...                        ...
# 4645          1            2       0            0                          2
# 4647          0            3       1            0                          2
# 4649          1            2       1            0                          2
# 4650          1            3       1            0                          5
# 4651          0            3       1            1                          2
#
# [2764 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
from sklearn.metrics import accuracy_score
def modelperformance(predictions):
    print("Accuracy score in model is {}".format(accuracy_score(y_test, predictions)))

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model.fit(scaled_X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_predictions = log_model.predict(scaled_X_test)
modelperformance(log_predictions)
# Out:
# Accuracy score in model is 0.674502712477396

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# %%
param_grid = {"n_neighbors" : [3, 5, 7, 9, 11],
             "weights" : ["uniform", "distance"],
             "algorithm" : ["auto", "ball_tree", "kd_tree", "brute"]}
gridkn = GridSearchCV(KNeighborsClassifier(), param_grid, cv = 2)
gridkn.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
print("Best Param :", gridkn.best_params_)
# Out:
# Best Param : {'algorithm': 'brute', 'n_neighbors': 9, 'weights': 'uniform'}

# %%
knpreds = gridkn.predict(scaled_X_test)
modelperformance(knpreds)
# Out:
# Accuracy score in model is 0.6419529837251357

# %%
from sklearn.svm import SVC
svm = SVC()
param_grid = {"C" : [0.01, 0.1, 0.5, 1],
             "kernel" : ["linear", "rbf", "poly"]}

# %%
gridsvc = GridSearchCV(svm, param_grid, cv = 3)
gridsvc.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
gridsvc.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
pred_svc = gridkn.predict(scaled_X_test)
modelperformance(pred_svc)
# Out:
# Accuracy score in model is 0.6419529837251357

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
models = {'DT' : DecisionTreeClassifier(), 
          'RF' : RandomForestClassifier(), 
          'KNN' : KNeighborsClassifier()}

# %%
for name, model in models.items() :
    print(name)
    print('-'*10)
    model.fit(scaled_X_train, y_train)
    y_pred = model.predict(scaled_X_test)
    
    ## score 
    modelperformance(y_pred)
#     print('Train Score', r2_score(y_train, model.predict(x_train)))
#     print('Validation Score', r2_score(y_test, y_pred))
    print('='*50)
# Out:
# DT
# ----------
# Accuracy score in model is 0.6889692585895117
# ==================================================
# RF
# ----------
# Accuracy score in model is 0.6817359855334539
# ==================================================
# KNN
# ----------
# Accuracy score in model is 0.6274864376130199
# ==================================================

# %%
param_grid = {
    "criterion" : ["gini","entropy"],
    "splitter" : ["best","random"],
    "max_depth" : [None, 10, 20, 30, 40, 50],
    "min_samples_split" : [2, 5, 10],
    "min_samples_leaf" : [1, 2 ,4]
}

# %%
grid_search_tree = GridSearchCV(DecisionTreeClassifier(), param_grid, cv = 3)
grid_search_tree.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid_search_tree.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
preds = grid_search_tree.predict(scaled_X_test)
modelperformance(preds)
# Out:
# Accuracy score in model is 0.6835443037974683

# %%
rfc_model = RandomForestClassifier()
n_estimators = [32, 64, 128, 256]
max_features = [2, 3, 4]
bootstrap = [True, False]
oob_score = [True, False]
param_grid = {"n_estimators" : n_estimators, "max_features" : max_features, "bootstrap" : bootstrap, "oob_score" : oob_score}
grid_rfc = GridSearchCV(rfc_model, param_grid, cv = 3)
grid_rfc.fit(scaled_X_train, y_train)
# Out:
# C:\Users\azrul\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 36 fits failed out of a total of 144.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\azrul\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\azrul\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\azrul\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 417, in fit
#     raise ValueError("Out of bag estimation only available if bootstrap=True")
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\azrul\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.654455   0.65355043 0.65897784 0.66259611 0.65264586 0.66395296
#  0.65988241 0.65309815 0.65174129 0.65852555 0.654455   0.65626413
#  0.6571687  0.65219358 0.65219358 0.654455   0.65988241 0.65535957
#  0.65671642 0.66259611 0.65671642 0.65626413 0.66033469 0.65897784
#         nan 0.66259611        nan 0.66259611        nan 0.66169154
#         nan 0.66259611        nan 0.66214383        nan 0.66304839
#         nan 0.66350068        nan 0.66304839        nan 0.66259611
#         nan 0.66350068        nan 0.66259611        nan 0.66350068]
#   warnings.warn(
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [32, 64, 128, 256],
#                          'oob_score': [True, False]})

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 2, 'n_estimators': 128, 'oob_score': False}

# %%
preds = grid_rfc.predict(scaled_X_test)
modelperformance(preds)
# Out:
# Accuracy score in model is 0.6853526220614828
