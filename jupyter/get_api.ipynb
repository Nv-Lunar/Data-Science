# %%
base_url = "https://v6.exchangerate-api.com/v6/de389d033c29fbb5234111d9/latest/USD"

# %%
import requests

# %%
res = requests.get(base_url)

# %%
res.ok
# Out:
# True

# %%
res.status_code
# Out:
# 200

# %%
res.json().keys()
# Out:
# dict_keys(['result', 'documentation', 'terms_of_use', 'time_last_update_unix', 'time_last_update_utc', 'time_next_update_unix', 'time_next_update_utc', 'base_code', 'target_code', 'conversion_rate', 'conversion_result'])

# %%
res.content
# Out:
# b'{\n "result":"success",\n "documentation":"https://www.exchangerate-api.com/docs",\n "terms_of_use":"https://www.exchangerate-api.com/terms",\n "time_last_update_unix":1704758401,\n "time_last_update_utc":"Tue, 09 Jan 2024 00:00:01 +0000",\n "time_next_update_unix":1704844801,\n "time_next_update_utc":"Wed, 10 Jan 2024 00:00:01 +0000",\n "base_code":"USD",\n "conversion_rates":{\n  "USD":1,\n  "AED":3.6725,\n  "AFN":71.2547,\n  "ALL":96.1317,\n  "AMD":405.3378,\n  "ANG":1.7900,\n  "AOA":843.2475,\n  "ARS":813.8500,\n  "AUD":1.4901,\n  "AWG":1.7900,\n  "AZN":1.6996,\n  "BAM":1.7858,\n  "BBD":2.0000,\n  "BDT":109.6317,\n  "BGN":1.7859,\n  "BHD":0.3760,\n  "BIF":2840.4514,\n  "BMD":1.0000,\n  "BND":1.3290,\n  "BOB":6.8057,\n  "BRL":4.8761,\n  "BSD":1.0000,\n  "BTN":83.0905,\n  "BWP":13.5853,\n  "BYN":3.2300,\n  "BZD":2.0000,\n  "CAD":1.3363,\n  "CDF":2697.6354,\n  "CHF":0.8486,\n  "CLP":890.9215,\n  "CNY":7.1620,\n  "COP":3965.8708,\n  "CRC":517.0785,\n  "CUP":24.0000,\n  "CVE":100.68
# ...

# %%
res.json()
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1704758401,
#  'time_last_update_utc': 'Tue, 09 Jan 2024 00:00:01 +0000',
#  'time_next_update_unix': 1704844801,
#  'time_next_update_utc': 'Wed, 10 Jan 2024 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 71.2547,
#   'ALL': 96.1317,
#   'AMD': 405.3378,
#   'ANG': 1.79,
#   'AOA': 843.2475,
#   'ARS': 813.85,
#   'AUD': 1.4901,
#   'AWG': 1.79,
#   'AZN': 1.6996,
#   'BAM': 1.7858,
#   'BBD': 2.0,
#   'BDT': 109.6317,
#   'BGN': 1.7859,
#   'BHD': 0.376,
#   'BIF': 2840.4514,
#   'BMD': 1.0,
#   'BND': 1.329,
#   'BOB': 6.8057,
#   'BRL': 4.8761,
#   'BSD': 1.0,
#   'BTN': 83.0905,
#   'BWP': 13.5853,
#   'BYN': 3.23,
#   'BZD': 2.0,
#   'CAD': 1.3363,
#   'CDF': 2697.6354,
#   'CHF': 0.8486,
#   'CLP': 890.9215,
#   'CNY': 7.162,
#   'COP': 3965.8708,
# ...

# %%
type(res.json())
# Out:
# dict

# %%
import json

# %%
json.dumps(res.json(), indent = 4)
# Out:
# '{\n    "result": "success",\n    "documentation": "https://www.exchangerate-api.com/docs",\n    "terms_of_use": "https://www.exchangerate-api.com/terms",\n    "time_last_update_unix": 1704758401,\n    "time_last_update_utc": "Tue, 09 Jan 2024 00:00:01 +0000",\n    "time_next_update_unix": 1704844801,\n    "time_next_update_utc": "Wed, 10 Jan 2024 00:00:01 +0000",\n    "base_code": "USD",\n    "conversion_rates": {\n        "USD": 1,\n        "AED": 3.6725,\n        "AFN": 71.2547,\n        "ALL": 96.1317,\n        "AMD": 405.3378,\n        "ANG": 1.79,\n        "AOA": 843.2475,\n        "ARS": 813.85,\n        "AUD": 1.4901,\n        "AWG": 1.79,\n        "AZN": 1.6996,\n        "BAM": 1.7858,\n        "BBD": 2.0,\n        "BDT": 109.6317,\n        "BGN": 1.7859,\n        "BHD": 0.376,\n        "BIF": 2840.4514,\n        "BMD": 1.0,\n        "BND": 1.329,\n        "BOB": 6.8057,\n        "BRL": 4.8761,\n        "BSD": 1.0,\n        "BTN": 83.0905,\n        "BWP": 13.5853,\n        "
# ...

# %%
print(json.dumps(res.json(), indent = 4))
# Out:
# {
#     "result": "success",
#     "documentation": "https://www.exchangerate-api.com/docs",
#     "terms_of_use": "https://www.exchangerate-api.com/terms",
#     "time_last_update_unix": 1704758401,
#     "time_last_update_utc": "Tue, 09 Jan 2024 00:00:01 +0000",
#     "time_next_update_unix": 1704844801,
#     "time_next_update_utc": "Wed, 10 Jan 2024 00:00:01 +0000",
#     "base_code": "USD",
#     "conversion_rates": {
#         "USD": 1,
#         "AED": 3.6725,
#         "AFN": 71.2547,
#         "ALL": 96.1317,
#         "AMD": 405.3378,
#         "ANG": 1.79,
#         "AOA": 843.2475,
#         "ARS": 813.85,
#         "AUD": 1.4901,
#         "AWG": 1.79,
#         "AZN": 1.6996,
#         "BAM": 1.7858,
#         "BBD": 2.0,
#         "BDT": 109.6317,
#         "BGN": 1.7859,
#         "BHD": 0.376,
#         "BIF": 2840.4514,
#         "BMD": 1.0,
#         "BND": 1.329,
#         "BOB": 6.8057,
#         "BRL": 4.8761,
#         "BSD": 1.0,
#         "BTN": 83.0905,
# ...

# %%
res.json().keys()
# Out:
# dict_keys(['result', 'documentation', 'terms_of_use', 'time_last_update_unix', 'time_last_update_utc', 'time_next_update_unix', 'time_next_update_utc', 'base_code', 'conversion_rates'])

# %% [markdown]
# # incorporating params Get Request

# %%
base_url = "https://v6.exchangerate-api.com/v6/de389d033c29fbb5234111d9/pair/"
param_url = base_url + "USD" + "/" + "JEP"
param_url
# Out:
# 'https://v6.exchangerate-api.com/v6/de389d033c29fbb5234111d9/pair/USD/JEP'

# %%
res = requests.get(param_url)
res
# Out:
# <Response [200]>

# %%
data = res.json()
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1704758401,
#  'time_last_update_utc': 'Tue, 09 Jan 2024 00:00:01 +0000',
#  'time_next_update_unix': 1704844801,
#  'time_next_update_utc': 'Wed, 10 Jan 2024 00:00:01 +0000',
#  'base_code': 'USD',
#  'target_code': 'JEP',
#  'conversion_rate': 0.7851}

# %%
data['base_code']
# Out:
# 'USD'

# %%
data['target_code']
# Out:
# 'JEP'

# %%
data['conversion_rate']
# Out:
# 0.7851

# %%
amount = 2
convert_rate = param_url + "?amount=" + str(amount)
convert_rate
# Out:
# 'https://v6.exchangerate-api.com/v6/de389d033c29fbb5234111d9/pair/USD/JEP?amount=2'

# %%
data = requests.get(param_url).json()
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1704758401,
#  'time_last_update_utc': 'Tue, 09 Jan 2024 00:00:01 +0000',
#  'time_next_update_unix': 1704844801,
#  'time_next_update_utc': 'Wed, 10 Jan 2024 00:00:01 +0000',
#  'base_code': 'USD',
#  'target_code': 'JEP',
#  'conversion_rate': 0.7851}

# %%
usd_to_jep = (
    "base_code = " + data['base_code'],
    "target_code = " + data['target_code'],
    "conversion_rate = " + str(data['conversion_rate']),
    "amount = " + str(amount)
)
usd_to_jep
# Out:
# ('base_code = USD',
#  'target_code = JEP',
#  'conversion_rate = 0.7851',
#  'amount = 2')

# %% [markdown]
# # obtaining historical exchange rates

# %%
base_url = "https://v6.exchangerate-api.com/v6/de389d033c29fbb5234111d9/"
historical_url = base_url + "history/USD/YEAR/MONTH/DAY"
historical_url
# Out:
# 'https://v6.exchangerate-api.com/v6/de389d033c29fbb5234111d9/history/USD/YEAR/MONTH/DAY'

# %% [markdown]
# # Creating simple curency

# %%
base_url = "https://v6.exchangerate-api.com/v6/de389d033c29fbb5234111d9/"
base_cur = input("Pilih mata uang yang anda miliki : ").upper()
target_cur = input("Pilih mata uang yang anda inginkan : ").upper()
amount = str(input("Tolong masukan jumlah mata uang yang akan anda tukarkan (angka !!!): "))
url = base_url + "pair" + "/" + base_cur + "/" + target_cur + "?" + "amount=" + amount
res = requests.get(url)

if(res.ok is False):
    print("\n Error {}: ".res.status_code)
    print(res.json())
else:
        data = res.json()
        rate = data['conversion_rate']
        print(f"\n nilai tukar : {data['conversion_rate']} \n {base_cur} {amount} sama dengan {target_cur} {data['conversion_result']}, berdasarkan nilai tukar pada {data['time_last_update_utc']}")

# if res.ok:
#     try:
#         data = res.json()
#         rate = data['conversion_rate']
#         print(f"\n nilai tukar : {data['conversion_rate']} \n {base_cur} {amount} sama dengan {target_cur} {data['conversion_result']}, berdasarkan nilai tukar pada {data['time_last_update_utc']}")
#     except ValueError as e:
#         print("Error decoding JSON:", e)
# else:
#     print(f"\nError {res.status_code}: {res.text}")
# Out:
# Pilih mata uang yang anda miliki : usd
# Pilih mata uang yang anda inginkan : jep
# Tolong masukan jumlah mata uang yang akan anda tukarkan : 10
# 0.7851 7.851

# %% [markdown]
# # Itunes

# %%
base_site = "https://itunes.apple.com/search"

# %%
url = base_site + "?term=dota+2&country=us"
requests.get(url)
# Out:
# <Response [200]>

# %%
res = requests.get(base_site, params = {"term": "dota 2", "country": "us"})
res.status_code
# Out:
# 200

# %%
res.url
# Out:
# 'https://itunes.apple.com/search?term=dota+2&country=us'

# %% [markdown]
# # Investigating the output and parameters

# %%
info = res.json()
print(json.dumps(info, indent = 4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 532447896,
#             "collectionId": 816471334,
#             "trackId": 816471502,
#             "artistName": "Video Games Live",
#             "collectionName": "Level 3",
#             "trackName": "Dota\u2122 2",
#             "collectionCensoredName": "Level 3",
#             "trackCensoredName": "Dota\u2122 2",
#             "artistViewUrl": "https://music.apple.com/us/artist/video-games-live/532447896?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/dota-2/816471334?i=816471502&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/dota-2/816471334?i=816471502&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/6f/46/e9/6f46e943-5c2a-5df8-d26e-151300496752/mzaf_8810981815188012989.plus.aac.p.m4a",
# ...

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
print(json.dumps(info['results'][10], indent=4))
# Out:
# {
#     "wrapperType": "track",
#     "kind": "song",
#     "artistId": 1531879671,
#     "collectionId": 1633439101,
#     "trackId": 1633439107,
#     "artistName": "Dinfinity, SkillaKilla & FROZEY",
#     "collectionName": "\u0411\u0410\u0425\u0427\u0418\u0421\u0410\u0420\u0410\u0419",
#     "trackName": "DOTA 2",
#     "collectionCensoredName": "\u0411\u0410\u0425\u0427\u0418\u0421\u0410\u0420\u0410\u0419",
#     "trackCensoredName": "DOTA 2",
#     "collectionArtistName": "Dinfinity",
#     "artistViewUrl": "https://music.apple.com/us/artist/dinfinity/1531879671?uo=4",
#     "collectionViewUrl": "https://music.apple.com/us/album/dota-2/1633439101?i=1633439107&uo=4",
#     "trackViewUrl": "https://music.apple.com/us/album/dota-2/1633439101?i=1633439107&uo=4",
#     "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview112/v4/00/7d/04/007d0438-c2dc-5829-545f-c6c94a8f4c07/mzaf_9109563342161477851.plus.aac.p.m4a",
# ...

# %%
res = requests.get(base_site, params = {"term": "dota 2", "country": "us", "limit": 200})
res.ok
# Out:
# True

# %%
res.json()["resultCount"]
# Out:
# 171

# %% [markdown]
# # Homework Itunes

# %%
# define base URL
base_site = "https://itunes.apple.com/search"
import requests
import json

# %%
res = requests.get(base_site, params = {"term": "the beatles", "country": "us", "limit": 200})
res.status_code
# Out:
# 200

# %%
res.json()["resultCount"]
# Out:
# 180

# %%
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 180,
#     "results": [
#         {
#             "wrapperType": "audiobook",
#             "artistId": 160778930,
#             "collectionId": 1439484338,
#             "artistName": "Bob Spitz",
#             "collectionName": "The Beatles (Abridged)",
#             "collectionCensoredName": "The Beatles (Abridged)",
#             "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#             "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#             "collectionPrice": 16.99,
#             "collectionExplicitness": "notExplicit",
# ...

# %%
# Find where the name is located
info['results'][1]['trackName']
# Out:
# 'The Beatles'

# %%
# Find where the release date is located
info['results'][0]['releaseDate']
# Out:
# '2005-11-01T08:00:00Z'

# %%
info = res.json()

# Check if "results" is present and not empty
if "results" in info and info["results"]:
    for result in info['results']:
        track_name = result.get('trackName', 'N/A')
        release_date = result.get('releaseDate', 'N/A')
        print(f"trackName : {track_name} \n releaseDate : {release_date}")
else:
    print("No results found.")
# Out:
# trackName : N/A
#  releaseDate : 2005-11-01T08:00:00Z
# trackName : The Beatles
#  releaseDate : 1983-05-01T12:00:00Z
# trackName : Pirates of the Caribbean: Dead Men Tell No Tales
#  releaseDate : 2017-05-26T07:00:00Z
# trackName : N/A
#  releaseDate : 2012-03-16T07:00:00Z
# trackName : The Beatles
#  releaseDate : 2005-09-12T12:00:00Z
# trackName : N/A
#  releaseDate : 2006-09-05T07:00:00Z
# trackName : The Beatles
#  releaseDate : 2010-03-15T12:00:00Z
# trackName : Popstar: Never Stop Never Stopping
#  releaseDate : 2016-06-03T07:00:00Z
# trackName : N/A
#  releaseDate : 2021-06-30T07:00:00Z
# trackName : N/A
#  releaseDate : 1999-02-01T08:00:00Z
# trackName : N/A
#  releaseDate : 2023-06-06T07:00:00Z
# trackName : The Beatles
#  releaseDate : 2006-04-18T12:00:00Z
# trackName : Bigger Than the Beatles
#  releaseDate : 1995-11-27T08:00:00Z
# trackName : N/A
#  releaseDate : 2022-05-13T07:00:00Z
# trackName : Hey Jude
#  releaseDate : 1968-08-26T12:00:00Z
# trackName : N/A
# ...
